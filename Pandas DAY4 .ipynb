# %%
import pandas as pd
import seaborn as sb
import numpy as np

# %%
df=pd.read_csv("weather_forecast_data.csv")

# %%
df
# Out:
#       Temperature   Humidity  Wind_Speed  Cloud_Cover     Pressure     Rain
# 0       23.720338  89.592641    7.335604    50.501694  1032.378759     rain
# 1       27.879734  46.489704    5.952484     4.990053   992.614190  no rain
# 2       25.069084  83.072843    1.371992    14.855784  1007.231620  no rain
# 3       23.622080  74.367758    7.050551    67.255282   982.632013     rain
# 4       20.591370  96.858822    4.643921    47.676444   980.825142  no rain
# ...           ...        ...         ...          ...          ...      ...
# 2495    21.791602  45.270902   11.807192    55.044682  1017.686181  no rain
# 2496    27.558479  46.481744   10.884915    39.715133  1008.590961  no rain
# 2497    28.108274  43.817178    2.897128    75.842952   999.119187  no rain
# 2498    14.789275  57.908105    2.374717     2.378743  1046.501875  no rain
# 2499    26.554356  97.101517   18.563084    81.357508  1001.729176  no rain
#
# [2500 rows x 6 columns]

# %%
sb.boxplot(x="Temperature",data=df)
# Out:
# <Axes: xlabel='Temperature'>

# %%
sb.boxplot(x="Humidity",data=df)
# Out:
# <Axes: xlabel='Humidity'>

# %%
sb.boxplot(x="Wind_Speed",data=df)
# Out:
# <Axes: xlabel='Wind_Speed'>

# %%
sb.boxplot(x="Cloud_Cover",data=df)
# Out:
# <Axes: xlabel='Cloud_Cover'>

# %%
sb.boxplot(x="Pressure",data=df)
# Out:
# <Axes: xlabel='Pressure'>

# %%
sb.boxplot(x="Rain",data=df)
# Out:
# <Axes: xlabel='Rain'>

# %%
def replace_outliers(df,column):
    Q1=df[column].quantile(0.25)
    Q3=df[column].quantile(0.75)

    IQR=Q3-Q1

    upper_bound=Q3+1.5*IQR  
    lower_bound=Q1-1.5*IQR

    # capping-replacing all higher values with upper bound (75% percentile)
    df[column]=np.where(df[column]>upper_bound,upper_bound,df[column])
    # flooring -replace all lower values with lower bound (25% percentile)
    df[column]=np.where(df[column]<lower_bound,lower_bound,df[column])
