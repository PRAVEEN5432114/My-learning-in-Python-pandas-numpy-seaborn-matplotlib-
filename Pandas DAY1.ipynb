# %%
import pandas as pd

# %%
df = pd.read_excel("Sales Analysis Report.xlsx")

# %%
df
# Out:
#        OrderNumber  OrderDate  Ship Date  Customer Name Index      Channel  \
# 0      SO - 000225 2017-01-01 2017-01-13                   28    Wholesale
# 1     SO - 0003378 2017-01-01 2017-01-06                    7  Distributor
# 2     SO - 0003901 2017-01-01 2017-01-05                   12    Wholesale
# 3     SO - 0005126 2017-01-01 2017-01-17                    5    Wholesale
# 4     SO - 0005614 2017-01-01 2017-01-07                   27       Export
# ...            ...        ...        ...                  ...          ...
# 7986  SO - 0005237 2019-12-12 2019-12-16                   41    Wholesale
# 7987  SO - 0005477 2019-12-12 2019-12-27                   28  Distributor
# 7988  SO - 0006936 2019-12-12 2019-12-27                   30    Wholesale
# 7989  SO - 0007126 2019-12-12 2019-12-25                    6  Distributor
# 7990  SO - 0007668 2019-12-12 2019-12-25                    4    Wholesale
#
#      Currency Code Warehouse Code  Region Index  Product  Index  \
# ...

# %%
df.shape
# Out:
# (7991, 13)

# %%
df.head()
# Out:
#     OrderNumber  OrderDate  Ship Date  Customer Name Index      Channel  \
# 0   SO - 000225 2017-01-01 2017-01-13                   28    Wholesale
# 1  SO - 0003378 2017-01-01 2017-01-06                    7  Distributor
# 2  SO - 0003901 2017-01-01 2017-01-05                   12    Wholesale
# 3  SO - 0005126 2017-01-01 2017-01-17                    5    Wholesale
# 4  SO - 0005614 2017-01-01 2017-01-07                   27       Export
#
#   Currency Code Warehouse Code  Region Index  Product  Index  Order Quantity  \
# 0           NZD         AXW291            71              11               6
# 1           NZD         AXW291            54               7              11
# 2           NZD         AXW291            58              13               5
# 3           USD         AXW291            29               7               6
# 4           NZD         AXW291            31               6               7
#
#    Unit Price  Total Unit Cost  Total Revenue
# ...

# %%
df.tail(9)
# Out:
#        OrderNumber  OrderDate  Ship Date  Customer Name Index      Channel  \
# 7982  SO - 0001226 2019-12-12 2019-12-26                   21    Wholesale
# 7983  SO - 0001900 2019-12-12 2019-12-28                   25  Distributor
# 7984  SO - 0003334 2019-12-12 2019-12-28                   28    Wholesale
# 7985  SO - 0003615 2019-12-12 2019-12-20                   45    Wholesale
# 7986  SO - 0005237 2019-12-12 2019-12-16                   41    Wholesale
# 7987  SO - 0005477 2019-12-12 2019-12-27                   28  Distributor
# 7988  SO - 0006936 2019-12-12 2019-12-27                   30    Wholesale
# 7989  SO - 0007126 2019-12-12 2019-12-25                    6  Distributor
# 7990  SO - 0007668 2019-12-12 2019-12-25                    4    Wholesale
#
#      Currency Code Warehouse Code  Region Index  Product  Index  \
# 7982           USD         FLR025            36               5
# 7983           USD         FLR025            33               5
# ...

# %%
df.columns
# Out:
# Index(['OrderNumber', 'OrderDate', 'Ship Date', 'Customer Name Index',
#        'Channel', 'Currency Code', 'Warehouse Code', 'Region Index',
#        'Product  Index', 'Order Quantity', 'Unit Price', 'Total Unit Cost',
#        'Total Revenue'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# OrderNumber            0
# OrderDate              0
# Ship Date              0
# Customer Name Index    0
# Channel                0
# Currency Code          0
# Warehouse Code         0
# Region Index           0
# Product  Index         0
# Order Quantity         0
# Unit Price             0
# Total Unit Cost        0
# Total Revenue          0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7991 entries, 0 to 7990
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   OrderNumber          7991 non-null   object
#  1   OrderDate            7991 non-null   datetime64[ns]
#  2   Ship Date            7991 non-null   datetime64[ns]
#  3   Customer Name Index  7991 non-null   int64
#  4   Channel              7991 non-null   object
#  5   Currency Code        7991 non-null   object
#  6   Warehouse Code       7991 non-null   object
#  7   Region Index         7991 non-null   int64
#  8   Product  Index       7991 non-null   int64
#  9   Order Quantity       7991 non-null   int64
#  10  Unit Price           7991 non-null   float64
#  11  Total Unit Cost      7991 non-null   float64
#  12  Total Revenue        7991 non-null   float64
# dtypes: datetime64[ns](2), float64(3), int64(4), object(4)
# memory usage: 811.7+ KB

# %%
df.describe()
# Out:
#                            OrderDate                      Ship Date  \
# count                           7991                           7991
# mean   2018-06-22 01:36:56.944061952  2018-07-02 12:04:35.710173952
# min              2017-01-01 00:00:00            2017-01-05 00:00:00
# 25%              2017-09-23 00:00:00            2017-10-03 00:00:00
# 50%              2018-06-20 00:00:00            2018-07-01 00:00:00
# 75%              2019-03-20 00:00:00            2019-04-01 00:00:00
# max              2019-12-12 00:00:00            2019-12-28 00:00:00
# std                              NaN                            NaN
#
#        Customer Name Index  Region Index  Product  Index  Order Quantity  \
# count          7991.000000   7991.000000     7991.000000     7991.000000
# mean             25.457014     50.454261        6.340383        8.456889
# min               1.000000      1.000000        1.000000        5.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7991 entries, 0 to 7990
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   OrderNumber          7991 non-null   object
#  1   OrderDate            7991 non-null   datetime64[ns]
#  2   Ship Date            7991 non-null   datetime64[ns]
#  3   Customer Name Index  7991 non-null   int64
#  4   Channel              7991 non-null   object
#  5   Currency Code        7991 non-null   object
#  6   Warehouse Code       7991 non-null   object
#  7   Region Index         7991 non-null   int64
#  8   Product  Index       7991 non-null   int64
#  9   Order Quantity       7991 non-null   int64
#  10  Unit Price           7991 non-null   float64
#  11  Total Unit Cost      7991 non-null   float64
#  12  Total Revenue        7991 non-null   float64
# dtypes: datetime64[ns](2), float64(3), int64(4), object(4)
# memory usage: 811.7+ KB

# %%
df["Region Index"].nunique()
# Out:
# 100

# %%
df["Region Index"].unique()
# Out:
# array([ 71,  54,  58,  29,  31,  78,   2,  77,  82,   5,  42,  87,  80,
#         38,  97,  88,   6,  95,  37,  53,  60,  47,  30,  63,  65,  27,
#         28,  83,  59,  99,  92,  23,  70,  25,  11, 100,  68,  39,  98,
#         41,  17,  72,  33,  64,  21,  19,   9,  46,  91,  79,  43,  10,
#         57,  84,   3,  55,  44,  51,  52,  36,   7,  40,  49,  16,  48,
#         26,  94,  66,  76,  22,   8,  34,  13,   1,  20,  15,  93,  50,
#         45,   4,  24,  35,  12,  14,  85,  73,  18,  62,  69,  89,  75,
#         81,  96,  74,  56,  90,  32,  67,  61,  86], dtype=int64)

# %%
df["Warehouse Code"].nunique()
# Out:
# 4

# %%
df["Warehouse Code"].unique()
# Out:
# array(['AXW291', 'GUT930', 'NXH382', 'FLR025'], dtype=object)

# %%
df.rename(columns={"Total Revenue":"Revenue"},inplace=True)

# %%
df.head()
# Out:
#     OrderNumber  OrderDate  Ship Date  Customer Name Index      Channel  \
# 0   SO - 000225 2017-01-01 2017-01-13                   28    Wholesale
# 1  SO - 0003378 2017-01-01 2017-01-06                    7  Distributor
# 2  SO - 0003901 2017-01-01 2017-01-05                   12    Wholesale
# 3  SO - 0005126 2017-01-01 2017-01-17                    5    Wholesale
# 4  SO - 0005614 2017-01-01 2017-01-07                   27       Export
#
#   Currency Code Warehouse Code  Region Index  Product  Index  Order Quantity  \
# 0           NZD         AXW291            71              11               6
# 1           NZD         AXW291            54               7              11
# 2           NZD         AXW291            58              13               5
# 3           USD         AXW291            29               7               6
# 4           NZD         AXW291            31               6               7
#
#    Unit Price  Total Unit Cost  Revenue
# ...

# %%
df.rename(columns={"Total Revenue":"Revenue"})
# Out:
#        OrderNumber  OrderDate  Ship Date  Customer Name Index      Channel  \
# 0      SO - 000225 2017-01-01 2017-01-13                   28    Wholesale
# 1     SO - 0003378 2017-01-01 2017-01-06                    7  Distributor
# 2     SO - 0003901 2017-01-01 2017-01-05                   12    Wholesale
# 3     SO - 0005126 2017-01-01 2017-01-17                    5    Wholesale
# 4     SO - 0005614 2017-01-01 2017-01-07                   27       Export
# ...            ...        ...        ...                  ...          ...
# 7986  SO - 0005237 2019-12-12 2019-12-16                   41    Wholesale
# 7987  SO - 0005477 2019-12-12 2019-12-27                   28  Distributor
# 7988  SO - 0006936 2019-12-12 2019-12-27                   30    Wholesale
# 7989  SO - 0007126 2019-12-12 2019-12-25                    6  Distributor
# 7990  SO - 0007668 2019-12-12 2019-12-25                    4    Wholesale
#
#      Currency Code Warehouse Code  Region Index  Product  Index  \
# ...

# %%
df.head()
# Out:
#     OrderNumber  OrderDate  Ship Date  Customer Name Index      Channel  \
# 0   SO - 000225 2017-01-01 2017-01-13                   28    Wholesale
# 1  SO - 0003378 2017-01-01 2017-01-06                    7  Distributor
# 2  SO - 0003901 2017-01-01 2017-01-05                   12    Wholesale
# 3  SO - 0005126 2017-01-01 2017-01-17                    5    Wholesale
# 4  SO - 0005614 2017-01-01 2017-01-07                   27       Export
#
#   Currency Code Warehouse Code  Region Index  Product  Index  Order Quantity  \
# 0           NZD         AXW291            71              11               6
# 1           NZD         AXW291            54               7              11
# 2           NZD         AXW291            58              13               5
# 3           USD         AXW291            29               7               6
# 4           NZD         AXW291            31               6               7
#
#    Unit Price  Total Unit Cost  Revenue
# ...

# %%
df.rename(columns={"Total Unit Cost":"Unit Cost"},inplace=True)

# %%
df.head()
# Out:
#     OrderNumber  OrderDate  Ship Date  Customer Name Index      Channel  \
# 0   SO - 000225 2017-01-01 2017-01-13                   28    Wholesale
# 1  SO - 0003378 2017-01-01 2017-01-06                    7  Distributor
# 2  SO - 0003901 2017-01-01 2017-01-05                   12    Wholesale
# 3  SO - 0005126 2017-01-01 2017-01-17                    5    Wholesale
# 4  SO - 0005614 2017-01-01 2017-01-07                   27       Export
#
#   Currency Code Warehouse Code  Region Index  Product  Index  Order Quantity  \
# 0           NZD         AXW291            71              11               6
# 1           NZD         AXW291            54               7              11
# 2           NZD         AXW291            58              13               5
# 3           USD         AXW291            29               7               6
# 4           NZD         AXW291            31               6               7
#
#    Unit Price  Unit Cost  Revenue
# 0      2499.1   1824.343  14994.6
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7991 entries, 0 to 7990
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   OrderNumber          7991 non-null   object
#  1   OrderDate            7991 non-null   datetime64[ns]
#  2   Ship Date            7991 non-null   datetime64[ns]
#  3   Customer Name Index  7991 non-null   int64
#  4   Channel              7991 non-null   object
#  5   Currency Code        7991 non-null   object
#  6   Warehouse Code       7991 non-null   object
#  7   Region Index         7991 non-null   int64
#  8   Product  Index       7991 non-null   int64
#  9   Order Quantity       7991 non-null   int64
#  10  Unit Price           7991 non-null   float64
#  11  Unit Cost            7991 non-null   float64
#  12  Revenue              7991 non-null   float64
# dtypes: datetime64[ns](2), float64(3), int64(4), object(4)
# memory usage: 874.0+ KB

# %%
df["Unit Cost"].sum()
# Out:
# 11442401.236000001

# %%
df["Unit Price"].sum()
# Out:
# 18255731.2

# %%
df["Unit Price"].max()
# Out:
# 6566.0

# %%
df["Unit Price"].min()
# Out:
# 167.5

# %%
df["Unit Price"].mean()
# Out:
# 2284.5365035665122

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7991 entries, 0 to 7990
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   OrderNumber          7991 non-null   object
#  1   OrderDate            7991 non-null   datetime64[ns]
#  2   Ship Date            7991 non-null   datetime64[ns]
#  3   Customer Name Index  7991 non-null   int64
#  4   Channel              7991 non-null   object
#  5   Currency Code        7991 non-null   object
#  6   Warehouse Code       7991 non-null   object
#  7   Region Index         7991 non-null   int64
#  8   Product  Index       7991 non-null   int64
#  9   Order Quantity       7991 non-null   int64
#  10  Unit Price           7991 non-null   float64
#  11  Unit Cost            7991 non-null   float64
#  12  Revenue              7991 non-null   float64
# dtypes: datetime64[ns](2), float64(3), int64(4), object(4)
# memory usage: 874.0+ KB

# %%
df.describe()
# Out:
#                            OrderDate                      Ship Date  \
# count                           7991                           7991
# mean   2018-06-22 01:36:56.944061952  2018-07-02 12:04:35.710173952
# min              2017-01-01 00:00:00            2017-01-05 00:00:00
# 25%              2017-09-23 00:00:00            2017-10-03 00:00:00
# 50%              2018-06-20 00:00:00            2018-07-01 00:00:00
# 75%              2019-03-20 00:00:00            2019-04-01 00:00:00
# max              2019-12-12 00:00:00            2019-12-28 00:00:00
# std                              NaN                            NaN
#
#        Customer Name Index  Region Index  Product  Index  Order Quantity  \
# count          7991.000000   7991.000000     7991.000000     7991.000000
# mean             25.457014     50.454261        6.340383        8.456889
# min               1.000000      1.000000        1.000000        5.000000
# ...

# %%
df.groupby("Channel")["Revenue"].sum()
# Out:
# Channel
# Distributor    48969690.3
# Export         22636874.6
# Wholesale      82966575.7
# Name: Revenue, dtype: float64

# %%
df.groupby("Channel")["Revenue"].max()
# Out:
# Channel
# Distributor    78550.8
# Export         77505.6
# Wholesale      78711.6
# Name: Revenue, dtype: float64

# %%
df.groupby("Channel")["Revenue"].min()
# Out:
# Channel
# Distributor    837.5
# Export         837.5
# Wholesale      837.5
# Name: Revenue, dtype: float64

# %%
df.groupby("Channel")["Revenue"].mean()
# Out:
# Channel
# Distributor    19509.836773
# Export         18942.991297
# Wholesale      19357.577158
# Name: Revenue, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7991 entries, 0 to 7990
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   OrderNumber          7991 non-null   object
#  1   OrderDate            7991 non-null   datetime64[ns]
#  2   Ship Date            7991 non-null   datetime64[ns]
#  3   Customer Name Index  7991 non-null   int64
#  4   Channel              7991 non-null   object
#  5   Currency Code        7991 non-null   object
#  6   Warehouse Code       7991 non-null   object
#  7   Region Index         7991 non-null   int64
#  8   Product  Index       7991 non-null   int64
#  9   Order Quantity       7991 non-null   int64
#  10  Unit Price           7991 non-null   float64
#  11  Total Unit Cost      7991 non-null   float64
#  12  Total Revenue        7991 non-null   float64
# dtypes: datetime64[ns](2), float64(3), int64(4), object(4)
# memory usage: 811.7+ KB

# %%
df["Customer Name Index"].sum()
# Out:
# 203427

# %%
df["Customer Name Index"].count()
# Out:
# 7991

# %%
df["Region Index"].unique()
# Out:
# array([ 71,  54,  58,  29,  31,  78,   2,  77,  82,   5,  42,  87,  80,
#         38,  97,  88,   6,  95,  37,  53,  60,  47,  30,  63,  65,  27,
#         28,  83,  59,  99,  92,  23,  70,  25,  11, 100,  68,  39,  98,
#         41,  17,  72,  33,  64,  21,  19,   9,  46,  91,  79,  43,  10,
#         57,  84,   3,  55,  44,  51,  52,  36,   7,  40,  49,  16,  48,
#         26,  94,  66,  76,  22,   8,  34,  13,   1,  20,  15,  93,  50,
#         45,   4,  24,  35,  12,  14,  85,  73,  18,  62,  69,  89,  75,
#         81,  96,  74,  56,  90,  32,  67,  61,  86], dtype=int64)

# %%
df["Region Index"].nunique()
# Out:
# 100

# %%
df.rename(columns={"Customer Name Index":"Customer"},inplace=True)

# %%
df.head()
# Out:
#     OrderNumber  OrderDate  Ship Date  Customer      Channel Currency Code  \
# 0   SO - 000225 2017-01-01 2017-01-13        28    Wholesale           NZD
# 1  SO - 0003378 2017-01-01 2017-01-06         7  Distributor           NZD
# 2  SO - 0003901 2017-01-01 2017-01-05        12    Wholesale           NZD
# 3  SO - 0005126 2017-01-01 2017-01-17         5    Wholesale           USD
# 4  SO - 0005614 2017-01-01 2017-01-07        27       Export           NZD
#
#   Warehouse Code  Region Index  Product  Index  Order Quantity  Unit Price  \
# 0         AXW291            71              11               6      2499.1
# 1         AXW291            54               7              11      2351.7
# 2         AXW291            58              13               5      1728.6
# 3         AXW291            29               7               6       978.2
# 4         AXW291            31               6               7      2338.3
#
#    Total Unit Cost  Total Revenue
# ...

# %%
df.rename(columns={"Product  Index":"Product"},inplace=True)

# %%
df.head()
# Out:
#     OrderNumber  OrderDate  Ship Date  Customer      Channel Currency Code  \
# 0   SO - 000225 2017-01-01 2017-01-13        28    Wholesale           NZD
# 1  SO - 0003378 2017-01-01 2017-01-06         7  Distributor           NZD
# 2  SO - 0003901 2017-01-01 2017-01-05        12    Wholesale           NZD
# 3  SO - 0005126 2017-01-01 2017-01-17         5    Wholesale           USD
# 4  SO - 0005614 2017-01-01 2017-01-07        27       Export           NZD
#
#   Warehouse Code  Region Index  Product  Order Quantity  Unit Price  \
# 0         AXW291            71       11               6      2499.1
# 1         AXW291            54        7              11      2351.7
# 2         AXW291            58       13               5      1728.6
# 3         AXW291            29        7               6       978.2
# 4         AXW291            31        6               7      2338.3
#
#    Total Unit Cost  Total Revenue
# 0         1824.343        14994.6
# 1         1269.918        25868.7
# ...

# %%
df.rename(columns={"Order Quantity":"Order"},inplace=True)

# %%
df.head()
# Out:
#     OrderNumber  OrderDate  Ship Date  Customer      Channel Currency Code  \
# 0   SO - 000225 2017-01-01 2017-01-13        28    Wholesale           NZD
# 1  SO - 0003378 2017-01-01 2017-01-06         7  Distributor           NZD
# 2  SO - 0003901 2017-01-01 2017-01-05        12    Wholesale           NZD
# 3  SO - 0005126 2017-01-01 2017-01-17         5    Wholesale           USD
# 4  SO - 0005614 2017-01-01 2017-01-07        27       Export           NZD
#
#   Warehouse Code  Region Index  Product  Order  Unit Price  Total Unit Cost  \
# 0         AXW291            71       11      6      2499.1         1824.343
# 1         AXW291            54        7     11      2351.7         1269.918
# 2         AXW291            58       13      5      1728.6         1019.874
# 3         AXW291            29        7      6       978.2          684.740
# 4         AXW291            31        6      7      2338.3         1028.852
#
#    Total Revenue
# 0        14994.6
# 1        25868.7
# ...

# %%
df.rename(columns={"Order":"Quantity"},inplace=True)

# %%
df.head()
# Out:
#     OrderNumber  OrderDate  Ship Date  Customer      Channel Currency Code  \
# 0   SO - 000225 2017-01-01 2017-01-13        28    Wholesale           NZD
# 1  SO - 0003378 2017-01-01 2017-01-06         7  Distributor           NZD
# 2  SO - 0003901 2017-01-01 2017-01-05        12    Wholesale           NZD
# 3  SO - 0005126 2017-01-01 2017-01-17         5    Wholesale           USD
# 4  SO - 0005614 2017-01-01 2017-01-07        27       Export           NZD
#
#   Warehouse Code  Region Index  Product  Quantity  Unit Price  \
# 0         AXW291            71       11         6      2499.1
# 1         AXW291            54        7        11      2351.7
# 2         AXW291            58       13         5      1728.6
# 3         AXW291            29        7         6       978.2
# 4         AXW291            31        6         7      2338.3
#
#    Total Unit Cost  Total Revenue
# 0         1824.343        14994.6
# 1         1269.918        25868.7
# 2         1019.874         8643.0
# ...

# %%
df.groupby("Warehouse Code")["Quantity"].sum()
# Out:
# Warehouse Code
# AXW291    31854
# FLR025     6868
# GUT930    15640
# NXH382    13217
# Name: Quantity, dtype: int64

# %%
df.groupby("Region Index")["Product"].sum()
# Out:
# Region Index
# 1      481
# 2      551
# 3      458
# 4      496
# 5      548
#       ...
# 96     561
# 97     493
# 98     473
# 99     554
# 100    501
# Name: Product, Length: 100, dtype: int64

# %%
df.groupby("Customer")["Region Index"].sum()
# Out:
# Customer
# 1      7614
# 2      6451
# 3      8966
# 4      8679
# 5      8167
# 6      7325
# 7      7619
# 8      7170
# 9      8044
# 10     7487
# 11     8874
# 12    10669
# 13     8727
# 14     7383
# 15     7411
# 16     7226
# 17     8453
# 18     9266
# 19     8292
# 20     7874
# 21     7803
# 22     6775
# 23     7993
# 24     7181
# 25     8973
# 26     7778
# 27     7377
# 28     7046
# 29     9054
# 30     7979
# 31     8240
# 32     8288
# 33     8185
# 34     8765
# 35     7095
# 36     8321
# 37     7817
# 38     7774
# 39     9493
# 40     7261
# 41     8797
# 42     8634
# 43     8045
# 44     8598
# 45     7947
# 46     7668
# 47     8503
# 48     8701
# 49     7362
# 50     8030
# Name: Region Index, dtype: int64

# %%
df["Product"].nunique()
# Out:
# 14

# %%
df["Product"].count()
# Out:
# 7991

# %%
df["Order Quantity"].sum()
# Out:
# 67579

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7991 entries, 0 to 7990
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   OrderNumber          7991 non-null   object
#  1   OrderDate            7991 non-null   datetime64[ns]
#  2   Ship Date            7991 non-null   datetime64[ns]
#  3   Customer Name Index  7991 non-null   int64
#  4   Channel              7991 non-null   object
#  5   Currency Code        7991 non-null   object
#  6   Warehouse Code       7991 non-null   object
#  7   Region Index         7991 non-null   int64
#  8   Product  Index       7991 non-null   int64
#  9   Order Quantity       7991 non-null   int64
#  10  Unit Price           7991 non-null   float64
#  11  Total Unit Cost      7991 non-null   float64
#  12  Total Revenue        7991 non-null   float64
# dtypes: datetime64[ns](2), float64(3), int64(4), object(4)
# memory usage: 811.7+ KB
