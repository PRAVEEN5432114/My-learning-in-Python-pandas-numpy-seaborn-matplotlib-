# %%
import pandas as pd

# %%
df=pd.read_excel("billing2.xlsx")

# %%
df
# Out:
#         name             Address model  quantity   Price  Amount
# 0     yukesh    kk nagar-chennai    RN         1     NaN     NaN
# 1    kishore  pallavaram-chennai    FN         1  1000.0     NaN
# 2     vidhya     t nagar-chennai    RN         3   500.0  1000.0
# 3     arisha    annur-coimbatore    FN         2     NaN     NaN
# 4  parthiban   koyembedu-chennai    RN         2   500.0     NaN
# 5   vaishnav    kk nagar-chennai    RN         4     NaN     NaN
# 6  parthiban     t nagar-chennai    RN         2   500.0  1000.0

# %%
df.isnull().sum()
# Out:
# name        0
# Address     0
# model       0
# quantity    0
# Price       3
# Amount      5
# dtype: int64

# %%
df[["AREA","CITY"]]=df["Address"].str.split("-",expand=True)

# %%
df
# Out:
#         name             Address model  quantity   Price  Amount        AREA  \
# 0     yukesh    kk nagar-chennai    RN         1     NaN     NaN    kk nagar
# 1    kishore  pallavaram-chennai    FN         1  1000.0     NaN  pallavaram
# 2     vidhya     t nagar-chennai    RN         3   500.0  1000.0     t nagar
# 3     arisha    annur-coimbatore    FN         2     NaN     NaN       annur
# 4  parthiban   koyembedu-chennai    RN         2   500.0     NaN   koyembedu
# 5   vaishnav    kk nagar-chennai    RN         4     NaN     NaN    kk nagar
# 6  parthiban     t nagar-chennai    RN         2   500.0  1000.0     t nagar
#
#          CITY
# 0     chennai
# 1     chennai
# 2     chennai
# 3  coimbatore
# 4     chennai
# 5     chennai
# 6     chennai

# %%
df.drop(columns=["Address"],inplace=True)

# %%
df
# Out:
#         name model  quantity   Price  Amount        AREA        CITY
# 0     yukesh    RN         1     NaN     NaN    kk nagar     chennai
# 1    kishore    FN         1  1000.0     NaN  pallavaram     chennai
# 2     vidhya    RN         3   500.0  1000.0     t nagar     chennai
# 3     arisha    FN         2     NaN     NaN       annur  coimbatore
# 4  parthiban    RN         2   500.0     NaN   koyembedu     chennai
# 5   vaishnav    RN         4     NaN     NaN    kk nagar     chennai
# 6  parthiban    RN         2   500.0  1000.0     t nagar     chennai

# %%
df.dropna()
# Out:
#         name model  quantity  Price  Amount     AREA     CITY
# 2     vidhya    RN         3  500.0  1000.0  t nagar  chennai
# 6  parthiban    RN         2  500.0  1000.0  t nagar  chennai

# %%
df
# Out:
#         name model  quantity   Price  Amount        AREA        CITY
# 0     yukesh    RN         1     NaN     NaN    kk nagar     chennai
# 1    kishore    FN         1  1000.0     NaN  pallavaram     chennai
# 2     vidhya    RN         3   500.0  1000.0     t nagar     chennai
# 3     arisha    FN         2     NaN     NaN       annur  coimbatore
# 4  parthiban    RN         2   500.0     NaN   koyembedu     chennai
# 5   vaishnav    RN         4     NaN     NaN    kk nagar     chennai
# 6  parthiban    RN         2   500.0  1000.0     t nagar     chennai

# %%
df["Price"].fillna(1000)
#df["Amount"]=df["Amount"].fillna(1000)
# Out:
# 0    1000.0
# 1    1000.0
# 2     500.0
# 3    1000.0
# 4     500.0
# 5    1000.0
# 6     500.0
# Name: Price, dtype: float64

# %%
df
# Out:
#         name model  quantity   Price  Amount        AREA        CITY
# 0     yukesh    RN         1     NaN     NaN    kk nagar     chennai
# 1    kishore    FN         1  1000.0     NaN  pallavaram     chennai
# 2     vidhya    RN         3   500.0  1000.0     t nagar     chennai
# 3     arisha    FN         2     NaN     NaN       annur  coimbatore
# 4  parthiban    RN         2   500.0     NaN   koyembedu     chennai
# 5   vaishnav    RN         4     NaN     NaN    kk nagar     chennai
# 6  parthiban    RN         2   500.0  1000.0     t nagar     chennai

# %%
df.ffill()
# Out:
#         name model  quantity   Price  Amount        AREA        CITY
# 0     yukesh    RN         1     NaN     NaN    kk nagar     chennai
# 1    kishore    FN         1  1000.0     NaN  pallavaram     chennai
# 2     vidhya    RN         3   500.0  1000.0     t nagar     chennai
# 3     arisha    FN         2   500.0  1000.0       annur  coimbatore
# 4  parthiban    RN         2   500.0  1000.0   koyembedu     chennai
# 5   vaishnav    RN         4   500.0  1000.0    kk nagar     chennai
# 6  parthiban    RN         2   500.0  1000.0     t nagar     chennai

# %%
df
# Out:
#         name model  quantity   Price  Amount        AREA        CITY
# 0     yukesh    RN         1     NaN     NaN    kk nagar     chennai
# 1    kishore    FN         1  1000.0     NaN  pallavaram     chennai
# 2     vidhya    RN         3   500.0  1000.0     t nagar     chennai
# 3     arisha    FN         2     NaN     NaN       annur  coimbatore
# 4  parthiban    RN         2   500.0     NaN   koyembedu     chennai
# 5   vaishnav    RN         4     NaN     NaN    kk nagar     chennai
# 6  parthiban    RN         2   500.0  1000.0     t nagar     chennai

# %%
df.bfill()
# Out:
#         name model  quantity   Price  Amount        AREA        CITY
# 0     yukesh    RN         1  1000.0  1000.0    kk nagar     chennai
# 1    kishore    FN         1  1000.0  1000.0  pallavaram     chennai
# 2     vidhya    RN         3   500.0  1000.0     t nagar     chennai
# 3     arisha    FN         2   500.0  1000.0       annur  coimbatore
# 4  parthiban    RN         2   500.0  1000.0   koyembedu     chennai
# 5   vaishnav    RN         4   500.0  1000.0    kk nagar     chennai
# 6  parthiban    RN         2   500.0  1000.0     t nagar     chennai

# %%
df
# Out:
#         name model  quantity   Price  Amount        AREA        CITY
# 0     yukesh    RN         1     NaN     NaN    kk nagar     chennai
# 1    kishore    FN         1  1000.0     NaN  pallavaram     chennai
# 2     vidhya    RN         3   500.0  1000.0     t nagar     chennai
# 3     arisha    FN         2     NaN     NaN       annur  coimbatore
# 4  parthiban    RN         2   500.0     NaN   koyembedu     chennai
# 5   vaishnav    RN         4     NaN     NaN    kk nagar     chennai
# 6  parthiban    RN         2   500.0  1000.0     t nagar     chennai

# %%
#ARRANGING VALUES USING sort_values

# %%
df.sort_values(by="quantity")
# Out:
#         name model  quantity   Price  Amount        AREA        CITY
# 0     yukesh    RN         1     NaN     NaN    kk nagar     chennai
# 1    kishore    FN         1  1000.0     NaN  pallavaram     chennai
# 3     arisha    FN         2     NaN     NaN       annur  coimbatore
# 4  parthiban    RN         2   500.0     NaN   koyembedu     chennai
# 6  parthiban    RN         2   500.0  1000.0     t nagar     chennai
# 2     vidhya    RN         3   500.0  1000.0     t nagar     chennai
# 5   vaishnav    RN         4     NaN     NaN    kk nagar     chennai

# %%
df
# Out:
#         name model  quantity   Price  Amount        AREA        CITY
# 0     yukesh    RN         1     NaN     NaN    kk nagar     chennai
# 1    kishore    FN         1  1000.0     NaN  pallavaram     chennai
# 2     vidhya    RN         3   500.0  1000.0     t nagar     chennai
# 3     arisha    FN         2     NaN     NaN       annur  coimbatore
# 4  parthiban    RN         2   500.0     NaN   koyembedu     chennai
# 5   vaishnav    RN         4     NaN     NaN    kk nagar     chennai
# 6  parthiban    RN         2   500.0  1000.0     t nagar     chennai

# %%
df=df.sort_values(by="quantity",ascending=False)

# %%
df
# Out:
#         name model  quantity   Price  Amount        AREA        CITY
# 5   vaishnav    RN         4     NaN     NaN    kk nagar     chennai
# 2     vidhya    RN         3   500.0  1000.0     t nagar     chennai
# 3     arisha    FN         2     NaN     NaN       annur  coimbatore
# 4  parthiban    RN         2   500.0     NaN   koyembedu     chennai
# 6  parthiban    RN         2   500.0  1000.0     t nagar     chennai
# 0     yukesh    RN         1     NaN     NaN    kk nagar     chennai
# 1    kishore    FN         1  1000.0     NaN  pallavaram     chennai

# %%
df.set_index("name")
# Out:
#           model  quantity   Price  Amount        AREA        CITY
# name
# vaishnav     RN         4     NaN     NaN    kk nagar     chennai
# vidhya       RN         3   500.0  1000.0     t nagar     chennai
# arisha       FN         2     NaN     NaN       annur  coimbatore
# parthiban    RN         2   500.0     NaN   koyembedu     chennai
# parthiban    RN         2   500.0  1000.0     t nagar     chennai
# yukesh       RN         1     NaN     NaN    kk nagar     chennai
# kishore      FN         1  1000.0     NaN  pallavaram     chennai

# %%
df
# Out:
#         name model  quantity   Price  Amount        AREA        CITY
# 5   vaishnav    RN         4     NaN     NaN    kk nagar     chennai
# 2     vidhya    RN         3   500.0  1000.0     t nagar     chennai
# 3     arisha    FN         2     NaN     NaN       annur  coimbatore
# 4  parthiban    RN         2   500.0     NaN   koyembedu     chennai
# 6  parthiban    RN         2   500.0  1000.0     t nagar     chennai
# 0     yukesh    RN         1     NaN     NaN    kk nagar     chennai
# 1    kishore    FN         1  1000.0     NaN  pallavaram     chennai

# %%
df.set_index("name",inplace=True)

# %%
df
# Out:
#           model  quantity   Price  Amount        AREA        CITY
# name
# vaishnav     RN         4     NaN     NaN    kk nagar     chennai
# vidhya       RN         3   500.0  1000.0     t nagar     chennai
# arisha       FN         2     NaN     NaN       annur  coimbatore
# parthiban    RN         2   500.0     NaN   koyembedu     chennai
# parthiban    RN         2   500.0  1000.0     t nagar     chennai
# yukesh       RN         1     NaN     NaN    kk nagar     chennai
# kishore      FN         1  1000.0     NaN  pallavaram     chennai

# %%
df.reset_index()
# Out:
#         name model  quantity   Price  Amount        AREA        CITY
# 0   vaishnav    RN         4     NaN     NaN    kk nagar     chennai
# 1     vidhya    RN         3   500.0  1000.0     t nagar     chennai
# 2     arisha    FN         2     NaN     NaN       annur  coimbatore
# 3  parthiban    RN         2   500.0     NaN   koyembedu     chennai
# 4  parthiban    RN         2   500.0  1000.0     t nagar     chennai
# 5     yukesh    RN         1     NaN     NaN    kk nagar     chennai
# 6    kishore    FN         1  1000.0     NaN  pallavaram     chennai

# %%
import pandas as pd
import numpy as np

# Create a dataset for the example (Time, Temperature, and Humidity)
data = {
    'Time': ['08:00', '09:00', '10:00', '11:00', '12:00', '13:00',],
    'Temperature': [22, 23, 26, 28, 30, 32],  # Increasing temperature
    'Humidity': [55, 63, np.nan, 66, np.nan, 68]  # Missing humidity at higher temperatures
}

# Convert to a DataFrame
df6 = pd.DataFrame(data)

# %%
df6
# Out:
#     Time  Temperature  Humidity
# 0  08:00           22      55.0
# 1  09:00           23      63.0
# 2  10:00           26       NaN
# 3  11:00           28      66.0
# 4  12:00           30       NaN
# 5  13:00           32      68.0

# %%
 df7=df6[["Temperature","Humidity"]]

# %%
df7
# Out:
#    Temperature  Humidity
# 0           22      55.0
# 1           23      63.0
# 2           26       NaN
# 3           28      66.0
# 4           30       NaN
# 5           32      68.0

# %%
df7.corr()
# Out:
#              Temperature  Humidity
# Temperature     1.000000  0.853642
# Humidity        0.853642  1.000000

# %%
import seaborn as sb

# %%
sb.scatterplot(x="Temperature",y="Humidity",data=df7)
# Out:
# <Axes: xlabel='Temperature', ylabel='Humidity'>

# %%
df7=df7.interpolate(method="polynomial",order=2)

# %%
df7
# Out:
#    Temperature   Humidity
# 0           22  55.000000
# 1           23  63.000000
# 2           26  65.705882
# 3           28  66.000000
# 4           30  66.764706
# 5           32  68.000000

# %%
df6=df7

# %%
df7
# Out:
#    Temperature   Humidity
# 0           22  55.000000
# 1           23  63.000000
# 2           26  65.705882
# 3           28  66.000000
# 4           30  66.764706
# 5           32  68.000000

# %%
df6
# Out:
#    Temperature   Humidity
# 0           22  55.000000
# 1           23  63.000000
# 2           26  65.705882
# 3           28  66.000000
# 4           30  66.764706
# 5           32  68.000000

# %%
import pandas as pd
import numpy as np

# Create a dataset for the example (Year and Population)
data = {
    'Year': ['2012','2013','2014','2018', '2019', '2020', '2021', '2022', '2023','2024'],#Year of th population calculated
    'Population Growth': [500,np.nan,100,np.nan,1200,np.nan,130,300,2200,np.nan],  # Population of Growth
      
}

# Convert to a DataFrame
df8 = pd.DataFrame(data)

# %%
df8.shape
# Out:
# (10, 2)

# %%
df8
# Out:
#    Year  Population Growth
# 0  2012              500.0
# 1  2013                NaN
# 2  2014              100.0
# 3  2018                NaN
# 4  2019             1200.0
# 5  2020                NaN
# 6  2021              130.0
# 7  2022              300.0
# 8  2023             2200.0
# 9  2024                NaN

# %%
df8.corr()
# Out:
#                        Year  Population Growth
# Year               1.000000           0.441619
# Population Growth  0.441619           1.000000

# %%
import seaborn as sb

# %%
sb.scatterplot(x="Year",y="Population Growth",data=df8)
# Out:
# <Axes: xlabel='Year', ylabel='Population Growth'>

# %%
df8.interpolate(method="linear")
# Out:
# C:\Users\D PRAVEEN\AppData\Local\Temp\ipykernel_4720\3666876173.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   df8.interpolate(method="linear")
#    Year  Population Growth
# 0  2012              500.0
# 1  2013              300.0
# 2  2014              100.0
# 3  2018              650.0
# 4  2019             1200.0
# 5  2020              665.0
# 6  2021              130.0
# 7  2022              300.0
# 8  2023             2200.0
# 9  2024             2200.0

# %%
df8.interpolate(method="polynomial",order=2)
# Out:
# C:\Users\D PRAVEEN\AppData\Local\Temp\ipykernel_4720\3010509228.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   df8.interpolate(method="polynomial",order=2)
#    Year  Population Growth
# 0  2012         500.000000
# 1  2013          19.983633
# 2  2014         100.000000
# 3  2018         740.049100
# 4  2019        1200.000000
# 5  2020         739.721768
# 6  2021         130.000000
# 7  2022         300.000000
# 8  2023        2200.000000
# 9  2024                NaN

# %%
df8.interpolate(method="cubic",order=3)
# Out:
# C:\Users\D PRAVEEN\AppData\Local\Temp\ipykernel_4720\2916049351.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   df8.interpolate(method="cubic",order=3)
#    Year  Population Growth
# 0  2012         500.000000
# 1  2013        -257.159091
# 2  2014         100.000000
# 3  2018         832.159091
# 4  2019        1200.000000
# 5  2020         744.772727
# 6  2021         130.000000
# 7  2022         300.000000
# 8  2023        2200.000000
# 9  2024                NaN

# %%
df8.interpolate(method="cubic",order=3)
# Out:
# C:\Users\D PRAVEEN\AppData\Local\Temp\ipykernel_4720\2916049351.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   df8.interpolate(method="cubic",order=3)
#    Year  Population Growth
# 0  2012         500.000000
# 1  2013        -257.159091
# 2  2014         100.000000
# 3  2018         832.159091
# 4  2019        1200.000000
# 5  2020         744.772727
# 6  2021         130.000000
# 7  2022         300.000000
# 8  2023        2200.000000
# 9  2024                NaN

# %%
df8.interpolate(method="quadratic",order=2)
# Out:
# C:\Users\D PRAVEEN\AppData\Local\Temp\ipykernel_4720\1890008843.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   df8.interpolate(method="quadratic",order=2)
#    Year  Population Growth
# 0  2012         500.000000
# 1  2013          19.983633
# 2  2014         100.000000
# 3  2018         740.049100
# 4  2019        1200.000000
# 5  2020         739.721768
# 6  2021         130.000000
# 7  2022         300.000000
# 8  2023        2200.000000
# 9  2024                NaN

# %%
df8
# Out:
#    Year  Population Growth
# 0  2012              500.0
# 1  2013                NaN
# 2  2014              100.0
# 3  2018                NaN
# 4  2019             1200.0
# 5  2020                NaN
# 6  2021              130.0
# 7  2022              300.0
# 8  2023             2200.0
# 9  2024                NaN
