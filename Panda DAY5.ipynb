# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_excel("Sales Analysis Report.xlsx")

# %%
df
# Out:
#        OrderNumber  OrderDate  Ship Date  Customer Name Index      Channel  \
# 0      SO - 000225 2017-01-01 2017-01-13                   28    Wholesale
# 1     SO - 0003378 2017-01-01 2017-01-06                    7  Distributor
# 2     SO - 0003901 2017-01-01 2017-01-05                   12    Wholesale
# 3     SO - 0005126 2017-01-01 2017-01-17                    5    Wholesale
# 4     SO - 0005614 2017-01-01 2017-01-07                   27       Export
# ...            ...        ...        ...                  ...          ...
# 7986  SO - 0005237 2019-12-12 2019-12-16                   41    Wholesale
# 7987  SO - 0005477 2019-12-12 2019-12-27                   28  Distributor
# 7988  SO - 0006936 2019-12-12 2019-12-27                   30    Wholesale
# 7989  SO - 0007126 2019-12-12 2019-12-25                    6  Distributor
# 7990  SO - 0007668 2019-12-12 2019-12-25                    4    Wholesale
#
#      Currency Code Warehouse Code  Region Index  Product  Index  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7991 entries, 0 to 7990
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   OrderNumber          7991 non-null   object
#  1   OrderDate            7991 non-null   datetime64[ns]
#  2   Ship Date            7991 non-null   datetime64[ns]
#  3   Customer Name Index  7991 non-null   int64
#  4   Channel              7991 non-null   object
#  5   Currency Code        7991 non-null   object
#  6   Warehouse Code       7991 non-null   object
#  7   Region Index         7991 non-null   int64
#  8   Product  Index       7991 non-null   int64
#  9   Order Quantity       7991 non-null   int64
#  10  Unit Price           7991 non-null   float64
#  11  Total Unit Cost      7991 non-null   float64
#  12  Total Revenue        7991 non-null   float64
# dtypes: datetime64[ns](2), float64(3), int64(4), object(4)
# memory usage: 811.7+ KB

# %%
df.rename(columns={"Customer Name Index":"customers","Region Index":"regions","Product  Index":"products","Order Quantity":"orders","Total Unit Cost":"unit cost","Total Revenue":"revenue"},inplace=True)

# %%
df.head()
# Out:
#     OrderNumber  OrderDate  Ship Date  customers      Channel Currency Code  \
# 0   SO - 000225 2017-01-01 2017-01-13         28    Wholesale           NZD
# 1  SO - 0003378 2017-01-01 2017-01-06          7  Distributor           NZD
# 2  SO - 0003901 2017-01-01 2017-01-05         12    Wholesale           NZD
# 3  SO - 0005126 2017-01-01 2017-01-17          5    Wholesale           USD
# 4  SO - 0005614 2017-01-01 2017-01-07         27       Export           NZD
#
#   Warehouse Code  regions  products  orders  Unit Price  unit cost  revenue
# 0         AXW291       71        11       6      2499.1   1824.343  14994.6
# 1         AXW291       54         7      11      2351.7   1269.918  25868.7
# 2         AXW291       58        13       5      1728.6   1019.874   8643.0
# 3         AXW291       29         7       6       978.2    684.740   5869.2
# 4         AXW291       31         6       7      2338.3   1028.852  16368.1

# %%
df.loc[:,["Channel","orders"]["products","Total Revenue"]]
# Out:
# <>:1: SyntaxWarning: list indices must be integers or slices, not tuple; perhaps you missed a comma?
# <>:1: SyntaxWarning: list indices must be integers or slices, not tuple; perhaps you missed a comma?
# C:\Users\D PRAVEEN\AppData\Local\Temp\ipykernel_6520\3294915707.py:1: SyntaxWarning: list indices must be integers or slices, not tuple; perhaps you missed a comma?
#   df.loc[:,["Channel","orders"]["products","Total Revenue"]]
# C:\Users\D PRAVEEN\AppData\Local\Temp\ipykernel_6520\3294915707.py:1: SyntaxWarning: list indices must be integers or slices, not tuple; perhaps you missed a comma?
#   df.loc[:,["Channel","orders"]["products","Total Revenue"]]
# C:\Users\D PRAVEEN\AppData\Local\Temp\ipykernel_6520\3294915707.py:1: SyntaxWarning: list indices must be integers or slices, not tuple; perhaps you missed a comma?
#   df.loc[:,["Channel","orders"]["products","Total Revenue"]]
# ...

# %%
df.set_index("customers",inplace=True)

# %%
df.head()
# Out:
#             OrderNumber  OrderDate  Ship Date      Channel Currency Code  \
# customers
# 28          SO - 000225 2017-01-01 2017-01-13    Wholesale           NZD
# 7          SO - 0003378 2017-01-01 2017-01-06  Distributor           NZD
# 12         SO - 0003901 2017-01-01 2017-01-05    Wholesale           NZD
# 5          SO - 0005126 2017-01-01 2017-01-17    Wholesale           USD
# 27         SO - 0005614 2017-01-01 2017-01-07       Export           NZD
#
#           Warehouse Code  regions  products  orders  Unit Price  unit cost  \
# customers
# 28                AXW291       71        11       6      2499.1   1824.343
# 7                 AXW291       54         7      11      2351.7   1269.918
# 12                AXW291       58        13       5      1728.6   1019.874
# 5                 AXW291       29         7       6       978.2    684.740
# 27                AXW291       31         6       7      2338.3   1028.852
#
#            revenue
# customers
# 28         14994.6
# ...

# %%
df.sort_index(inplace=True)

# %%
df.loc[1:10,["Channel","OrderDate"]]
# Out:
#                Channel  OrderDate
# customers
# 1          Distributor 2018-05-21
# 1            Wholesale 2017-08-18
# 1            Wholesale 2018-10-02
# 1            Wholesale 2018-02-02
# 1          Distributor 2019-05-10
# ...                ...        ...
# 10              Export 2017-03-28
# 10           Wholesale 2017-02-14
# 10           Wholesale 2017-02-12
# 10         Distributor 2018-09-10
# 10              Export 2017-03-27
#
# [1561 rows x 2 columns]

# %%
df["Channel"].unique()
# Out:
# array(['Distributor', 'Wholesale', 'Export'], dtype=object)

# %%
data_exports=df.loc[df["Channel"]=="Export"]
data_exports
# Out:
#             OrderNumber  OrderDate  Ship Date Channel Currency Code  \
# customers
# 1          SO - 0004336 2017-03-15 2017-03-26  Export           NZD
# 1          SO - 0007426 2019-04-17 2019-04-22  Export           NZD
# 1          SO - 0005639 2017-02-13 2017-02-20  Export           USD
# 1          SO - 0003499 2018-09-10 2018-09-16  Export           AUD
# 1          SO - 0002172 2019-06-06 2019-06-11  Export           AUD
# ...                 ...        ...        ...     ...           ...
# 50         SO - 0004132 2018-07-27 2018-08-08  Export           AUD
# 50         SO - 0001810 2017-07-22 2017-07-25  Export           NZD
# 50         SO - 0003361 2017-02-26 2017-03-11  Export           EUR
# 50         SO - 0007679 2019-01-26 2019-02-12  Export           AUD
# 50         SO - 0005854 2019-07-11 2019-07-23  Export           EUR
#
#           Warehouse Code  regions  products  orders  Unit Price  unit cost  \
# customers
# ...

# %%
df["Currency Code"].unique()
# Out:
# array(['NZD', 'USD', 'AUD', 'GBP', 'EUR'], dtype=object)

# %%
df.loc[(df["Channel"]=="Export")&(df["Currency Code"]=="USD")]
# Out:
#             OrderNumber  OrderDate  Ship Date Channel Currency Code  \
# customers
# 1          SO - 0005639 2017-02-13 2017-02-20  Export           USD
# 1          SO - 0001416 2018-09-16 2018-09-26  Export           USD
# 1          SO - 0003477 2019-02-07 2019-02-19  Export           USD
# 1          SO - 0005251 2017-11-17 2017-11-21  Export           USD
# 1           SO - 000511 2019-12-03 2019-12-10  Export           USD
# ...                 ...        ...        ...     ...           ...
# 50         SO - 0007151 2017-05-16 2017-05-28  Export           USD
# 50         SO - 0001350 2019-02-05 2019-02-20  Export           USD
# 50         SO - 0003188 2019-03-17 2019-04-02  Export           USD
# 50         SO - 0007090 2017-11-16 2017-11-24  Export           USD
# 50         SO - 0004268 2018-05-09 2018-05-19  Export           USD
#
#           Warehouse Code  regions  products  orders  Unit Price  unit cost  \
# customers
# ...

# %%
df.loc[(df["Channel"]=="Wholesale") & (df["Currency Code"]=="USD") & (df["orders"]==5)]
# Out:
#             OrderNumber  OrderDate  Ship Date    Channel Currency Code  \
# customers
# 1          SO - 0006329 2019-07-09 2019-07-21  Wholesale           USD
# 1          SO - 0005047 2019-03-19 2019-04-04  Wholesale           USD
# 1          SO - 0003347 2018-11-29 2018-12-17  Wholesale           USD
# 1          SO - 0007591 2018-05-14 2018-05-29  Wholesale           USD
# 1          SO - 0001471 2017-06-10 2017-06-18  Wholesale           USD
# ...                 ...        ...        ...        ...           ...
# 49         SO - 0001588 2017-07-02 2017-07-19  Wholesale           USD
# 50         SO - 0002983 2019-05-02 2019-05-08  Wholesale           USD
# 50         SO - 0003547 2017-08-22 2017-09-06  Wholesale           USD
# 50         SO - 0004482 2018-07-08 2018-07-21  Wholesale           USD
# 50         SO - 0006660 2018-06-29 2018-07-02  Wholesale           USD
#
#           Warehouse Code  regions  products  orders  Unit Price  unit cost  \
# customers
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7991 entries, 1 to 50
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   OrderNumber     7991 non-null   object
#  1   OrderDate       7991 non-null   datetime64[ns]
#  2   Ship Date       7991 non-null   datetime64[ns]
#  3   Channel         7991 non-null   object
#  4   Currency Code   7991 non-null   object
#  5   Warehouse Code  7991 non-null   object
#  6   regions         7991 non-null   int64
#  7   products        7991 non-null   int64
#  8   orders          7991 non-null   int64
#  9   Unit Price      7991 non-null   float64
#  10  unit cost       7991 non-null   float64
#  11  revenue         7991 non-null   float64
# dtypes: datetime64[ns](2), float64(3), int64(3), object(4)
# memory usage: 1.0+ MB

# %%
df
# Out:
#             OrderNumber  OrderDate  Ship Date      Channel Currency Code  \
# customers
# 1           SO - 000942 2018-05-21 2018-06-07  Distributor           NZD
# 1           SO - 000798 2017-08-18 2017-09-01    Wholesale           USD
# 1          SO - 0007537 2018-10-02 2018-10-19    Wholesale           NZD
# 1          SO - 0001209 2018-02-02 2018-02-19    Wholesale           USD
# 1          SO - 0006258 2019-05-10 2019-05-24  Distributor           USD
# ...                 ...        ...        ...          ...           ...
# 50         SO - 0003284 2019-04-19 2019-05-05    Wholesale           GBP
# 50         SO - 0001056 2019-03-25 2019-04-07  Distributor           NZD
# 50         SO - 0007341 2017-12-01 2017-12-14  Distributor           USD
# 50         SO - 0002406 2019-09-23 2019-09-30  Distributor           NZD
# 50         SO - 0005854 2019-07-11 2019-07-23       Export           EUR
#
#           Warehouse Code  regions  products  orders  Unit Price  unit cost  \
# ...

# %%
pd.to_datetime(df["OrderDate"])
df["YEAR"]=df["OrderDate"].dt.year
df["MONTH"]=df["OrderDate"].dt.month_name()
df["DAYS"]=df["OrderDate"].dt.day_name()

# %%
df.head()
# Out:
#             OrderNumber  OrderDate  Ship Date      Channel Currency Code  \
# customers
# 1           SO - 000942 2018-05-21 2018-06-07  Distributor           NZD
# 1           SO - 000798 2017-08-18 2017-09-01    Wholesale           USD
# 1          SO - 0007537 2018-10-02 2018-10-19    Wholesale           NZD
# 1          SO - 0001209 2018-02-02 2018-02-19    Wholesale           USD
# 1          SO - 0006258 2019-05-10 2019-05-24  Distributor           USD
#
#           Warehouse Code  regions  products  orders  Unit Price  unit cost  \
# customers
# 1                 GUT930        7         2       9      1031.8    515.900
# 1                 AXW291       78         7      10      2311.5   1525.590
# 1                 GUT930       46         7       7      1989.9   1114.344
# 1                 AXW291       62         9      12       174.2    114.972
# 1                 NXH382       32         1      11      3946.3   1657.446
#
#            revenue  YEAR     MONTH     DAYS
# ...

# %%
df.group_by[(df["revenue"].sum()) & df["YEAR"]==2018]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6520\2575895022.py in ?()
# ----> 1 df.Group_by[(df["revenue"].sum()) & df["YEAR"]==2018]
#
# C:\New folder\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'Group_by'

# %%
df["YEAR"].unique()
# Out:
# array([2018, 2017, 2019])

# %%
df["weekday"]=df["OrderDate"].dt.weekday

# %%
df.head()
# Out:
#             OrderNumber  OrderDate  Ship Date      Channel Currency Code  \
# customers
# 1           SO - 000942 2018-05-21 2018-06-07  Distributor           NZD
# 1           SO - 000798 2017-08-18 2017-09-01    Wholesale           USD
# 1          SO - 0007537 2018-10-02 2018-10-19    Wholesale           NZD
# 1          SO - 0001209 2018-02-02 2018-02-19    Wholesale           USD
# 1          SO - 0006258 2019-05-10 2019-05-24  Distributor           USD
#
#           Warehouse Code  regions  products  orders  Unit Price  unit cost  \
# customers
# 1                 GUT930        7         2       9      1031.8    515.900
# 1                 AXW291       78         7      10      2311.5   1525.590
# 1                 GUT930       46         7       7      1989.9   1114.344
# 1                 AXW291       62         9      12       174.2    114.972
# 1                 NXH382       32         1      11      3946.3   1657.446
#
# ...

# %%
df["WEEKEND"]=df["weekday"].apply(lambda x: "Weekend" if x>=5 else "weekdays")

# %%
df.head()
# Out:
#             OrderNumber  OrderDate  Ship Date      Channel Currency Code  \
# customers
# 1           SO - 000942 2018-05-21 2018-06-07  Distributor           NZD
# 1           SO - 000798 2017-08-18 2017-09-01    Wholesale           USD
# 1          SO - 0007537 2018-10-02 2018-10-19    Wholesale           NZD
# 1          SO - 0001209 2018-02-02 2018-02-19    Wholesale           USD
# 1          SO - 0006258 2019-05-10 2019-05-24  Distributor           USD
#
#           Warehouse Code  regions  products  orders  Unit Price  unit cost  \
# customers
# 1                 GUT930        7         2       9      1031.8    515.900
# 1                 AXW291       78         7      10      2311.5   1525.590
# 1                 GUT930       46         7       7      1989.9   1114.344
# 1                 AXW291       62         9      12       174.2    114.972
# 1                 NXH382       32         1      11      3946.3   1657.446
#
# ...

# %%
df.iloc[0:10,2:10]
# Out:
#            Ship Date      Channel Currency Code Warehouse Code  regions  \
# customers
# 1         2018-06-07  Distributor           NZD         GUT930        7
# 1         2017-09-01    Wholesale           USD         AXW291       78
# 1         2018-10-19    Wholesale           NZD         GUT930       46
# 1         2018-02-19    Wholesale           USD         AXW291       62
# 1         2019-05-24  Distributor           USD         NXH382       32
# 1         2019-05-24  Distributor           AUD         NXH382       14
# 1         2017-08-27  Distributor           AUD         AXW291       58
# 1         2017-09-06  Distributor           GBP         AXW291       56
# 1         2017-03-26       Export           NZD         AXW291       60
# 1         2017-08-24    Wholesale           USD         AXW291       67
#
#            products  orders  Unit Price
# customers
# 1                 2       9      1031.8
# 1                 7      10      2311.5
# ...

# %%
df["Maunfacture Price"]=df["orders"]*df["unit cost"]
df["Profit"]=df["revenue"]-df["Maunfacture Price"]

# %%
df.head()
# Out:
#             OrderNumber  OrderDate  Ship Date      Channel Currency Code  \
# customers
# 1           SO - 000942 2018-05-21 2018-06-07  Distributor           NZD
# 1           SO - 000798 2017-08-18 2017-09-01    Wholesale           USD
# 1          SO - 0007537 2018-10-02 2018-10-19    Wholesale           NZD
# 1          SO - 0001209 2018-02-02 2018-02-19    Wholesale           USD
# 1          SO - 0006258 2019-05-10 2019-05-24  Distributor           USD
#
#           Warehouse Code  regions  products  orders  Unit Price  unit cost  \
# customers
# 1                 GUT930        7         2       9      1031.8    515.900
# 1                 AXW291       78         7      10      2311.5   1525.590
# 1                 GUT930       46         7       7      1989.9   1114.344
# 1                 AXW291       62         9      12       174.2    114.972
# 1                 NXH382       32         1      11      3946.3   1657.446
#
# ...

# %%
df["SEPMONTH"]=df["MONTH"].apply(lambda x: "first" if x in["January","Feburary","March","April","May","June"] else "second")
df
# Out:
#             OrderNumber  OrderDate  Ship Date      Channel Currency Code  \
# customers
# 1           SO - 000942 2018-05-21 2018-06-07  Distributor           NZD
# 1           SO - 000798 2017-08-18 2017-09-01    Wholesale           USD
# 1          SO - 0007537 2018-10-02 2018-10-19    Wholesale           NZD
# 1          SO - 0001209 2018-02-02 2018-02-19    Wholesale           USD
# 1          SO - 0006258 2019-05-10 2019-05-24  Distributor           USD
# ...                 ...        ...        ...          ...           ...
# 50         SO - 0003284 2019-04-19 2019-05-05    Wholesale           GBP
# 50         SO - 0001056 2019-03-25 2019-04-07  Distributor           NZD
# 50         SO - 0007341 2017-12-01 2017-12-14  Distributor           USD
# 50         SO - 0002406 2019-09-23 2019-09-30  Distributor           NZD
# 50         SO - 0005854 2019-07-11 2019-07-23       Export           EUR
#
#           Warehouse Code  regions  products  orders  Unit Price  unit cost  \
# ...
